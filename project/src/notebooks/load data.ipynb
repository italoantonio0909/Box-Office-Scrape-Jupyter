# %%
import os
import pandas

BASE_DIR= os.path.dirname(os.getcwd())
DONWLOAD_DIR= os.path.join(BASE_DIR,'data')
DATA=os.path.join(DOWNLOAD_DIR , 'boxofficemojo.com-2015.csv')

df=pandas.read_csv(DATA)
df.sort_values(by=['Worldwide'],inplace=True)
df['Rank']=df.index+1
df.head()
# Out:
#      Rank         Release Group   Worldwide    Domestic      %     Foreign  \
# 851   852    Comment c'est loin  $1,001,196           -      -  $1,001,196
# 850   851  Faith of Our Fathers  $1,004,105  $1,004,105   100%           -
# 849   850       Sinister Circle  $1,004,914           -      -  $1,004,914
# 848   849           Francofonia  $1,008,154    $307,040  30.5%    $701,114
# 847   848          Far from Men  $1,010,485      $5,336   0.5%  $1,005,149
#
#        %.1
# 851   100%
# 850      -
# 849   100%
# 848  69.5%
# 847  99.5%
